# %% [markdown]
# ### **Student Information**
# Name: 蔡坤憲
#
# Student ID: 111034043
#
# GitHub ID: RforRico
#
# Kaggle name: KunHsien_Tsai
#
# Kaggle private scoreboard snapshot:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](./pics/lab2_deadlines.png)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
# **Syntax:** `#` creates the largest heading (H1).
#
# ---
# **Syntax:** `---` creates a horizontal rule (a separator line).
#
# ## 1. Model Development (10 pts Required)
#
# **Syntax:** `##` creates a secondary heading (H2).
#
# **Describe briefly each section, you can add graphs/charts to support your explanations.**
#
# ### 1.1 Preprocessing Steps
#
# **Syntax:** `###` creates a tertiary heading (H3).
#
# [Content for Preprocessing]
#
# **Example Syntax for Content:**
# *   **Bold text:** `**text**`
# *   *Italic text*: `*text*`
# *   Bullet point list:
#     * Item 1
#     * Item 2
#
# Markdown Syntax to Add Image: `![Description of the Image](./your_local_folder/name_of_the_image.png)`
#
# ![Example Markdown Syntax to Add Image](./pics/example_md_img.png)
#
# ### 1.2 Feature Engineering Steps
#
# (1) Word-level TF–IDF
#
# (2) Character-level TF–IDF
#
# ### 1.3 Explanation of Your Model
#
# Logistic Regression
#
# Multinomial Naive Bayes
#
# Ensemble (soft voting)
#
# ---
#
# ## 2. Bonus Section (5 pts Optional)
#
# **Add more detail in previous sections**
#
# ### 2.1 Mention Different Things You Tried
#
# I tried several different models and feature settings instead of sticking to just one baseline. I first used logistic regression with word-level TF–IDF, then added character-level TF–IDF and some simple style features. I trained both logistic regression and Multinomial Naive Bayes on these features and then combined them using a soft-voting ensemble. I also briefly played with a transformer-based model, but it was too slow on my local machine. In the end, I picked the ensemble with the enhanced TF–IDF features as my best setup based on macro F1 on the validation set.
#
# (12/2)
# (1) add a third base model (calibrated Linear SVM) and let Naive Bayes use pure TF–IDF features
# (2) replace manual weighting with a stacking ensemble.
# I concatenate the predicted class probabilities from all three base models into a meta-feature and train a second-layer Logistic Regression to learn how to combine them. I then compare all single models and the stacking model on the validation set and use the best one for the final test predictions.
#
# ### 2.2 Mention Insights You Gained
#
# From these experiments I realized that improving features mattered more than just switching models. Adding character-level TF–IDF and simple style features helped the minority classes more than changing the classifier. Macro F1 also made the class imbalance very clear, so I had to care about disgust and fear, not only joy. Finally, a simple ensemble of logistic regression and Naive Bayes gave a small but consistent gain with almost no extra cost.
#
# ---

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
import json
import os
import re
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

from scipy.sparse import hstack

DATA_PATH = "./"

# %%
id_df      = pd.read_csv(f"{DATA_PATH}/data_identification.csv")
emotion_df = pd.read_csv(f"{DATA_PATH}/emotion.csv")

with open(f"{DATA_PATH}/final_posts.json", "r", encoding="utf-8") as f:
    raw_posts = json.load(f)

# Convert to DataFrame: id, text
post_rows = []
for item in raw_posts:
    post = item["root"]["_source"]["post"]
    pid = post["post_id"]
    text = post.get("text", "")
    hashtags = post.get("hashtags", [])

    if hashtags:
        full_text = text + " " + " ".join(f"#{h}" for h in hashtags)
    else:
        full_text = text

    post_rows.append({"id": pid, "text": full_text})

posts_df = pd.DataFrame(post_rows)

# Merge split and emotion info
all_data = posts_df.merge(id_df, on="id", how="left")
all_data = all_data.merge(emotion_df, on="id", how="left")  # test rows have NaN emotion

train_df = all_data[all_data["split"] == "train"].copy()
test_df  = all_data[all_data["split"] == "test"].copy()

print("Train shape:", train_df.shape)
print("Test shape :", test_df.shape)

# Text and labels
train_text_full = train_df["text"].fillna("")
train_labels    = train_df["emotion"]

x_train_text, x_valid_text, y_train, y_valid = train_test_split(
    train_text_full,
    train_labels,
    test_size=0.2,
    random_state=42,
    stratify=train_labels,
)

x_test_text = test_df["text"].fillna("")
# Out:
# Train shape: (47890, 4)
# Test shape : (16281, 4)

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import FeatureUnion
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import classification_report, f1_score
from scipy.sparse import hstack
import numpy as np

def build_style_features(text_series: pd.Series) -> np.ndarray:

    rows = []
    for text in text_series.astype(str):
        char_len = len(text)
        words    = text.split()
        word_len = len(words)

        num_qmark  = text.count("?")
        num_exclam = text.count("!")
        num_dots   = text.count("...")

        num_upper_words = sum(
            1 for w in words
            if (len(w) >= 2 and w.isupper())
        )

        rows.append([
            np.log1p(char_len),
            np.log1p(word_len),
            num_exclam,
            num_qmark,
            num_upper_words,
            num_dots,
        ])
    return np.array(rows, dtype=np.float32)


train_text_clean = x_train_text.fillna("")
valid_text_clean = x_valid_text.fillna("")
test_text_clean  = x_test_text.fillna("")

# Word-level TF-IDF
word_vectorizer = TfidfVectorizer(
    max_features=60000,
    ngram_range=(1, 2),
    sublinear_tf=True,
    min_df=2,
)

# Character-level TF-IDF
char_vectorizer = TfidfVectorizer(
    analyzer="char_wb",
    ngram_range=(3, 5),
    min_df=3,
    max_features=30000,
)

# Combine word + char features
tfidf_union = FeatureUnion([
    ("word", word_vectorizer),
    ("char", char_vectorizer),
])

x_train_tfidf = tfidf_union.fit_transform(train_text_clean)
x_valid_tfidf = tfidf_union.transform(valid_text_clean)
x_test_tfidf  = tfidf_union.transform(test_text_clean)

print("TF-IDF shapes (train / valid / test):")
print("  train:", x_train_tfidf.shape)
print("  valid:", x_valid_tfidf.shape)
print("  test :", x_test_tfidf.shape)

# Style features (dense)
style_train = build_style_features(train_text_clean)
style_valid = build_style_features(valid_text_clean)
style_test  = build_style_features(test_text_clean)

print("Style feature shape (train):", style_train.shape)

x_train_feat = hstack([x_train_tfidf, style_train])
x_valid_feat = hstack([x_valid_tfidf, style_valid])
x_test_feat  = hstack([x_test_tfidf,  style_test])

print("Final feature shapes (train / valid / test):")
print("  train:", x_train_feat.shape)
print("  valid:", x_valid_feat.shape)
print("  test :", x_test_feat.shape)


logit_clf = LogisticRegression(
    max_iter=1000,
    solver="lbfgs",
    multi_class="auto",
    C=2.0,                
    class_weight="balanced",
)

print("\n[Logistic Regression] fitting ...")
logit_clf.fit(x_train_feat, y_train)

valid_pred_logit  = logit_clf.predict(x_valid_feat)
valid_proba_logit = logit_clf.predict_proba(x_valid_feat)

macro_f1_logit = f1_score(y_valid, valid_pred_logit, average="macro")
print("Logistic macro F1:", macro_f1_logit)
print("Logistic valid report:")
print(classification_report(y_valid, valid_pred_logit))


nb_clf = MultinomialNB(alpha=0.5)

print("\n[MultinomialNB] fitting ...")
nb_clf.fit(x_train_tfidf, y_train)

valid_pred_nb  = nb_clf.predict(x_valid_tfidf)
valid_proba_nb = nb_clf.predict_proba(x_valid_tfidf)

macro_f1_nb = f1_score(y_valid, valid_pred_nb, average="macro")
print("Naive Bayes macro F1:", macro_f1_nb)
print("Naive Bayes valid report:")
print(classification_report(y_valid, valid_pred_nb))


svm_base = LinearSVC(
    C=1.0,
    class_weight="balanced",
    max_iter=5000,
)

svm_clf = CalibratedClassifierCV(svm_base, cv=3)

print("\n[LinearSVC] fitting (with calibration) ...")
svm_clf.fit(x_train_feat, y_train)

valid_pred_svm  = svm_clf.predict(x_valid_feat)
valid_proba_svm = svm_clf.predict_proba(x_valid_feat)

macro_f1_svm = f1_score(y_valid, valid_pred_svm, average="macro")
print("LinearSVC macro F1:", macro_f1_svm)
print("LinearSVC valid report:")
print(classification_report(y_valid, valid_pred_svm))

class_labels = logit_clf.classes_
# Out:
# TF-IDF shapes (train/valid/test):
#   train: (38312, 89679)
#   valid: (9578, 89679)
#   test : (16281, 89679)
# Style feature shape: (38312, 6)
# Final feature shapes:
#   train: (38312, 89685)
#   valid: (9578, 89685)
#   test : (16281, 89685)
#
# === Fit Logistic Regression ===
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic macro F1: 0.4653589281398529
# Logistic valid report:
#               precision    recall  f1-score   support
#
#        anger       0.54      0.56      0.55      2139
#      disgust       0.17      0.19      0.18       237
#         fear       0.38      0.52      0.44       402
#          joy       0.81      0.69      0.74      4759
#      sadness       0.35      0.41      0.38       785
#     surprise       0.45      0.56      0.50      1256
#
#     accuracy                           0.60      9578
#    macro avg       0.45      0.49      0.47      9578
# weighted avg       0.63      0.60      0.61      9578
#
#
# === Fit MultinomialNB ===
# Naive Bayes macro F1: 0.32432947206292057
# Naive Bayes valid report:
#               precision    recall  f1-score   support
#
#        anger       0.56      0.53      0.55      2139
#      disgust       0.00      0.00      0.00       237
#         fear       0.75      0.11      0.19       402
#          joy       0.62      0.91      0.74      4759
#      sadness       0.70      0.09      0.17       785
#     surprise       0.63      0.20      0.31      1256
#
#     accuracy                           0.61      9578
#    macro avg       0.54      0.31      0.32      9578
# weighted avg       0.61      0.61      0.55      9578
#
#
# === Fit LinearSVC + CalibratedClassifierCV ===
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\super\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC macro F1: 0.4159224271502458
# LinearSVC valid report:
#               precision    recall  f1-score   support
#
#        anger       0.56      0.53      0.55      2139
#      disgust       0.60      0.04      0.07       237
#         fear       0.60      0.30      0.40       402
#          joy       0.67      0.88      0.76      4759
#      sadness       0.57      0.18      0.28       785
#     surprise       0.58      0.36      0.44      1256
#
#     accuracy                           0.63      9578
#    macro avg       0.60      0.38      0.42      9578
# weighted avg       0.62      0.63      0.60      9578

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
from sklearn.linear_model import LogisticRegression

# Collect base model probabilities on test set
test_proba_logit = logit_clf.predict_proba(x_test_feat)
test_proba_nb    = nb_clf.predict_proba(x_test_tfidf)
test_proba_svm   = svm_clf.predict_proba(x_test_feat)


meta_valid = np.hstack([
    valid_proba_logit,
    valid_proba_nb,
    valid_proba_svm,
])

meta_test = np.hstack([
    test_proba_logit,
    test_proba_nb,
    test_proba_svm,
])

print("Meta feature shapes:")
print("  valid:", meta_valid.shape)
print("  test :", meta_test.shape)


meta_clf = LogisticRegression(
    max_iter=1000,
    multi_class="auto",
    solver="lbfgs",
    class_weight="balanced",
)

print("\n[Stacking] fitting meta logistic ...")
meta_clf.fit(meta_valid, y_valid)

valid_pred_meta = meta_clf.predict(meta_valid)
macro_f1_meta   = f1_score(y_valid, valid_pred_meta, average="macro")

print("Stacking (meta logistic) macro F1:", macro_f1_meta)
print("Stacking valid report:")
print(classification_report(y_valid, valid_pred_meta))


scores_on_valid = {
    "logit":    macro_f1_logit,
    "nb":       macro_f1_nb,
    "svm":      macro_f1_svm,
    "stacking": macro_f1_meta,
}

print("\nValidation macro F1 summary:")
for name, score in scores_on_valid.items():
    print(f"  {name:8s}: {score:.4f}")

best_model_name = max(scores_on_valid, key=scores_on_valid.get)
best_model_f1   = scores_on_valid[best_model_name]

print(f"\n>>> Best model on validation: {best_model_name} (macro F1 = {best_model_f1:.4f})")


if best_model_name == "logit":
    print("Using Logistic Regression for test prediction.")
    test_pred = logit_clf.predict(x_test_feat)
    model_tag = "logit"

elif best_model_name == "nb":
    print("Using MultinomialNB for test prediction.")
    test_pred = nb_clf.predict(x_test_tfidf)
    model_tag = "nb"

elif best_model_name == "svm":
    print("Using LinearSVC (calibrated) for test prediction.")
    test_pred = svm_clf.predict(x_test_feat)
    model_tag = "svm"

elif best_model_name == "stacking":
    print("Using Stacking (meta logistic) for test prediction.")
    test_pred = meta_clf.predict(meta_test)
    model_tag = "stacking_logit_nb_svm"

else:
    print("Unexpected case, falling back to Logistic Regression.")
    test_pred = logit_clf.predict(x_test_feat)
    model_tag = "logit_fallback"


sample_sub = pd.read_csv(f"{DATA_PATH}/samplesubmission.csv")
id_to_label = dict(zip(test_df["id"], test_pred))
sample_sub["emotion"] = sample_sub["id"].map(id_to_label)

output_file = f"submission_{model_tag}.csv"
sample_sub.to_csv(output_file, index=False)

print("\nSaved submission file:", output_file)
# Out:
# === 2-model ensemble (logit + NB): coarse search ===
# Coarse best 2-model weights (logit, nb): (0.8, 0.19999999999999996) macro F1: 0.4740662111198557
#
# === 2-model ensemble (logit + NB): fine search around best ===
# Final best 2-model weights (logit, nb): (0.7800000000000001, 0.21999999999999986) macro F1: 0.4763066029152965
#
# === 3-model ensemble (logit + NB + SVM): coarse search ===
# Coarse best 3-model weights (logit, nb, svm): (0.8, 0.0, 0.19999999999999996) macro F1: 0.47342593032041264
#
# === 3-model ensemble (logit + NB + SVM): fine search around best ===
# Final best 3-model weights (logit, nb, svm): (0.7000000000000001, 0.0, 0.29999999999999993) macro F1: 0.47716728356076454
#
# Best single model on valid: logit, macro F1 = 0.4654
#
# === Gating: single-model vs 2-model ensemble ===
#   threshold = 0.60: macro F1 = 0.4763
#   threshold = 0.65: macro F1 = 0.4763
#   threshold = 0.70: macro F1 = 0.4763
#   threshold = 0.75: macro F1 = 0.4763
#   threshold = 0.80: macro F1 = 0.4763
#   threshold = 0.85: macro F1 = 0.4763
#   threshold = 0.90: macro F1 = 0.4763
# Best gating2 (single=logit vs 2-model) threshold = 0.60, macro F1 = 0.4763
#
# Candidate scores: {'logit': 0.4653589281398529, '2model': 0.4763066029152965, '3model': 0.47716728356076454, 'gating2': 0.4763066029152965}
#
# >>> Best choice on validation: 3model macro F1: 0.47716728356076454
# >>> Use 3-model ensemble (logit + NB + SVM) for test prediction
# Saved submission file: submission_ens_logit_nb_svm.csv
